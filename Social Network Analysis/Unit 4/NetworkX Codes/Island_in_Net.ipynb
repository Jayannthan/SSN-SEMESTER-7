# %%
import networkx as nx

g = nx.read_pajek("/egypt_retweets.net")
len(g)
# Out:
# 25178

# %%
nx.number_connected_components(g)
# Out:
# 3122

# %%
import matplotlib.pyplot as plot
x = [len(c) for c in nx.connected_components(g)]
plot.hist(x)
# Out:
# (array([3.121e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([1.00000e+00, 1.77710e+03, 3.55320e+03, 5.32930e+03, 7.10540e+03,
#         8.88150e+03, 1.06576e+04, 1.24337e+04, 1.42098e+04, 1.59859e+04,
#         1.77620e+04]),
#  <a list of 10 Patch objects>)

# %%
cc = nx.connected_components(g)
[len(c) for c in nx.connected_components(g) if len(c) > 10]
print(list(cc))
# Out:
# [{'manuelvl', 'msmabroable', 'cnnAM', 'thehaitian', 'PlanetPOV', 'JeffHandley', 'Jude_X', 'AJRizKhan', 'cmunozcamos', 'aseryehia', 'yearn_soo', 'bsebti', 'zakwanhaj', 'BKKKabiri', 'Semanticus', 'Alihabib313', '20arb11', 'danielschut', 'Lamagouille', 'Intelligent_A', 'pastormontagne', 'BE_PURE', 'free4ever_92', 'MichaMeskalinas', 'wigunadarma', 'BrettMason10', 'issyvb', 'AlexDavidson82', 'Josh_Sigurdson', 'NeilBhatiya', 'nmoawad', '1791obmij', 'abdulaziz_sh', 'ambisitham', 'RamyMahrous', 'festivelyplump', '5ZA', 'antoesp', 'mkholif', 'Egocrata', 'MatthewNordin', 'u_dai1985', 'dwonline', 'xx_im_kim_xx', 'belkyspc', 'TamerMA', 'FitoTN', 'jmcesteves', 'Debby78', 'JORGELAND', 'Saifnuq', 'TheCatWhoDesign', 'HailaKhalaf', 'MohamedANassar', 'pktp', 'ben_hr', 'NoorBreish', 'feenicks', 'mariamaarouf', 'ahmedabulmagd', 'Croisan', 'quota_atypique', 'MishaHAli', 'phyz925', 'MoeAliNayel', 'ro0ose90', 'Straub48', 'malailam', 'RalFehaid', 'sofiJah', 'alogne', 'rbakercnn', 'shiro_neko_tama', 'TH61', 'ahmsayat', 'BareeqBarqawi', 'Miss_Eman', 'TheBlindOwl2', 'hossam_salama', 'mrsbosco', 'azzazaza', 'BigEasyMuc', 'will_ford', 'alveolarplosive', 'gheryania', 'AndreaMassaroni', 'HananMubarak', 'garyinflorida', 'defusertt', 'BlogsofWar', '0xraouf', 'david_7even', 'veronicapalm', 'MuseAndVent', 'EduardoThome', 'dmitriblack', 'justender', 'jehswong', 'mrjaimisra', 'elraey', 'chootkapani', 'nana4_chick', 'pakistanpolicy', 'pascaluccelli', 'HinDahmash', 'ahmedelbadry555', 'LynnePDX', 'Hazeemov', 'RaquelEvita', '_LosAngeles', 'Sabbathcafe88', 'piathabia', 'sarahvaill', 'NPR', 'EhabZ', 'Mars_Amr', 'Motamaredah', 'cjlambert', 'j_salcedo', 'abouaymenz', 'carondelet', 'ericadarragh', 'Palinspired', 'Efesoshera', 'denspw', 'DrLeeGo', 'Disncubanita', 'FreeTunis', 'MAbuShanab', 'OMARCUBANO', 'TheCamelsNose', 'RawdhaAlJaradi', 'safeworld4all', 'hajjaram', 'Victoria_cars', 'jpiedrahita', 'rami_issa', 'Kerstinify', 'mike_arney', '_ummah', 'FatmaNaib', 'lobachevscki', 'sumitgarg07', 'an0o0la', 'HCorderoGuzman', 'msicc', 'Lifehacker', 'stephtelesco', 'AymanNasreldin', 'hectorcitox', 'ptypk', 'ghonem', 'AhmidDredar', 'ksayeds', 'alexwdc', 'janosizoltan', 'TZidaroff', 'LeReveur86', 'keithellison', 'TweetMags', 'CathyGellis', 'ManitouHeights', 'philippebossin', 'Greytdog', 'falahalharbi', 'usa', 'JSmithTK', 'DeyaaEldeen', 'Humbuka', 'egyptia', 'Abou_3ali', '2ezem', 'HybridStates', 'mohamed10011', 'XCulture', 'Sharon59', 'Demonoid55', 'CauseGlobal', 'Aegyptoc', 'Aziz_Yahya', 'christokane', 'MAHMOUD_EL_KADY', 'iQnasSudeer', 'Shorouk_News', 'GobVenezuela', 'sayedseif', 'petroleocrudo', 'TamimHamd', 'o2izzuddin', 'ReemHany307', 'JimLenoir', 'CampaignReboot', 'netfreedom', 'tauriqmoosa', 'deewin', 'zecataaaa', 'marwsay', 'Fernando_Duarte', 'bbcworldservice', 'jrug', 'Eslam_Daoud', 'primavera2000_', 'Ramose83', 'rodeo2011', 'em0987654321', 'mraouf7', 'MennatAllah87', 'AmerAlSaleh', 'TheVoleAnon', 'RosettaBroy', 'bbcme', 'vikingomartell', 'translator82', 'zacbailes', 'Amane_Hayyal', 'nahedmancyp', 'BRADYCOMPANY', 'SangyeH', 'joamettegil', 'marshray', 'PinballGraham', 'zonkinoff', 'Organica', 'ehabmes', 'niklasf', 'nash181', 'rawritsphoebe', 'JoeKubrick', 'thewtb', 'polepoleguevara', 'jgberenguer', 'mediripyou', 'WebiMedias', 'SpeakerBoehner', 'matto8', 'Arabic_News', 'FromJoanne', '_hatman', 'abdozcom', 'Bya3elgraid', 'HotShotDebater', 'GJMcGinn', 'nigrovic', 'idsolemn', 'ThePinebox', 'jem126', 'JordanSekulow', 'rebeccaromani', 'Monno88', 'inspectorlopez', 'jasoncnj', 'dahlmustafa', 'Falasteeni', 'gehtdochnicht', 'summerwine888', 'BasharAsad', 'estonedus', 'sarahbethlynch', 'DCPlod', 'dazedsaveends', 'sunili', 'ExitPass', 'mroamk', 'arababah', 'jonronson', 'demotix', 'SlateStoneMusic', 'suchenwi', 'CSadeem', 'Sarah_Kholusi', 'herrkusuma', 'electric589', 'ahmedabdelaziz1', 'SendoPolitico', 'Egyptian_Agenda', 'Lastoadri', 'Lucky550', 'readwriteweb', 'KristyRae44657', 'ReFlex76', 'scrawford', 'REY_T', 'modyisindafront', 'ReFounderParty', 'rattlecans', 'bing', 'AbdallahMazhar', ' ...

# %%
def island_method(g, iterations=5):
    weights = [edata['weight'] for f, to, edata in g.edges(data=True)]
    mn = int(min(weights))
    mx = int(max(weights))
    # compute the size of the step, so we get a reasonable step in iterations
    step = int((mx-mn)/iterations)
    return [[threshold, trim_edges(g, threshold)] for threshold in range(mn, mx, step)]

# %%
cc = nx.node_connected_component(g)
islands = island_method(cc)

for i in islands:
    print(i[0], len(i[1]), len(nx.connected_component_subgraphs(i[1])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-6b2ad5abc75b> in <module>
# ----> 1 cc=nx.node_connected_component(g, 0)
#       2 islands=island_method(cc)
#       3
#       4 for i in islands:
#       5     print (i[0], len(i[1]), len(nx.connected_component_subgraphs(i[1])))
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in argmap_node_connected_component_14(G, n)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/components/connected.py in node_connected_component(G, n)
#     170
#     171     """
# --> 172     return _plain_bfs(G, n)
#     173
#     174
#
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/components/connected.py in _plain_bfs(G, source)
#     184             if v not in seen:
#     185                 seen.add(v)
# --> 186                 nextlevel.update(G_adj[v])
#     187     return seen
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/coreviews.py in __getitem__(self, name)
#     102
#     103     def __getitem__(self, name):
# --> 104         return AdjacencyView(self._atlas[name])
#     105
#     106     def copy(self):
#
# KeyError: 0
